# %%
# %run db.ipynb
# Out:
# Query started at 11:41:15 AM EDT
# Query executed in 0.00 m
# Query started at 11:41:15 AM EDT
# Query executed in 0.00 m

# %% [markdown]
# ## Load Data

# %%
traindf = pd.read_csv('../input/train.csv')
weatherdf = pd.read_csv('../input/weather.csv')
spraydf = pd.read_csv('../input/spray.csv')
# testdf = pd.read_csv('../input/test.csv')

# %%
schema = 'wnv'
traindf.rename({'Date': 'DateStr', 'Trap': 'TrapID'})
traindf.to_sql('wnv_train', engine, schema=schema, index = False,
               if_exists = 'replace', chunksize=1000)
weatherdf.to_sql('wnv_weather', engine, schema=schema, index = False,
               if_exists = 'replace', chunksize=1000)
spraydf.to_sql('wnv_spray', engine, schema=schema, index = False,
               if_exists = 'replace', chunksize=1000)
del traindf, weatherdf, spraydf

# %%
# %%read_sql
# SELECT *
# FROM wnv.wnv_weather
# LIMIT 10
# Out:
# Query started at 03:35:12 PM EDT
# Query executed in 0.00 m
# <a id="1498073712"></a>
#
#         <script>
#         function notifyMe() {
#           if (Notification.permission !== "granted")
#             Notification.requestPermission();
#           else {
#             var notification = new Notification('Query Finished in 0.00 m', {
#               icon: 'https://raw.githubusercontent.com/crawles/Logos/master/jupyter.png?raw=true',
#               body: "03:35:12 PM EDT\n\nName: None\nDimensions: (10, 22)",
#             });
#
#             notification.onclick = function () {
#               document.getElementById('1498073712').scrollIntoView();
#             };
#
#           }
#         }
#         // prevents notifications from popping up when notebook is re-opened
#         if (Date.now() < 1.49807371385e+12) {
#         notifyMe(); };
#         </script>
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        1  2007-05-02    59    42   51     -3        42      47   14    0
# 2        1  2007-05-03    66    46   56      2        40      48    9    0
# 3        1  2007-05-04    66    49   58      4        41      50    7    0
# 4        1  2007-05-05    66    53   60      5        38      49    5    0
# 5        1  2007-05-06    68    49   59      4        30      46    6    0
# 6        1  2007-05-07    83    47   65     10        41      54    0    0
# 7        1  2007-05-08    82    54   68     12        58      62    0    3
# 8        1  2007-05-09    77    61   69     13        59      63    0    4
# 9        1  2007-05-10    84    56   70     14        52      60    0    5
#
#      ...    CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 0    ...                0      M      0.0        0.00       29.10    29.82
# 1    ...         BR     0      M      0.0        0.00       29.38    30.09
# 2    ...                0      M      0.0        0.00       29.39    30.12
# 3    ...         RA     0      M      0.0           T       29.31    30.05
# 4    ...                0      M      0.0           T       29.40    30.10
# 5    ...                0      M      0.0        0.00       29.57    30.29
# 6    ...         RA     0      M      0.0           T       29.38    30.12
# 7    ...         BR     0      M      0.0        0.00       29.29    30.03
# 8    ...      BR HZ     0      M      0.0        0.13       29.21    29.94
# 9    ...         BR     0      M      0.0        0.00       29.20    29.92
#
#   ResultSpeed ResultDir  AvgSpeed
# 0         1.7        27       9.2
# 1        13.0         4      13.4
# 2        11.7         7      11.9
# 3        10.4         8      10.8
# 4        11.7         7      12.0
# 5        14.4        11      15.0
# 6         8.6        18      10.5
# 7         2.7        11       5.8
# 8         3.9         9       6.2
# 9         0.7        17       4.1
#
# [10 rows x 22 columns]
