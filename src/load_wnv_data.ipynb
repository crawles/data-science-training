# %%
# %run db.ipynb
# Out:
# The sql_magic extension is already loaded. To reload it, use:
#   %reload_ext sql_magic
# Query started at 04:22:58 PM EDT
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-27-ecc8c5e61ba9> in <module>()
# ----> 1 get_ipython().magic(u'read_sql DROP SCHEMA wnv;')
#       2 get_ipython().magic(u'read_sql CREATE SCHEMA wnv;')
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2334         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2335         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2336         return self.run_line_magic(magic_name, magic_arg_s)
#    2337
#    2338     #-------------------------------------------------------------------------
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2255                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2256             with self.builtin_trap:
# -> 2257                 result = fn(*args,**kwargs)
#    2258             return result
#    2259
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sql_magic/sql_magic.pyc in read_sql(self, line, cell, local_ns)
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sql_magic/sql_magic.pyc in read_sql(self, line, cell, local_ns)
#      97             t.start()
#      98         else:
# ---> 99             result = self.conn.execute_sqls(statements, options)
#     100             if options['display']:
#     101                 return result
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sql_magic/connection.pyc in execute_sqls(self, sqls, options)
#      95     def execute_sqls(self, sqls, options):
#      96         for i, s in enumerate(sqls, start=1):
# ---> 97             r = self._read_sql_engine(s, options)
#      98         return r
#      99
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sql_magic/connection.pyc in _read_sql_engine(self, sql, options)
#      81         else:
#      82             caller = self.caller
# ---> 83         result, del_time = self._time_and_run_query(caller, sql)
#      84
#      85         if table_name:
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sql_magic/connection.pyc in _time_and_run_query(self, caller, sql)
#     102         print('Query started at {}'.format(pretty_start_time))
#     103         start_time = time.time()
# --> 104         result = caller(sql)
#     105         end_time = time.time()
#     106         del_time = (end_time - start_time) / 60.
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sql_magic/connection.pyc in _run_db_sql(sql_code)
#      35         def _run_db_sql(sql_code):
#      36             try:
# ---> 37                 return psql.read_sql(sql_code, conn_object)
#      38             except(tuple(self.no_return_result_exceptions)):
#      39                 return EmptyResult()
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/pandas/io/sql.pyc in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     413             sql, index_col=index_col, params=params,
#     414             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 415             chunksize=chunksize)
#     416
#     417
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/pandas/io/sql.pyc in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1082         args = _convert_params(sql, params)
#    1083
# -> 1084         result = self.execute(*args)
#    1085         columns = result.keys()
#    1086
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/pandas/io/sql.pyc in execute(self, *args, **kwargs)
#     973     def execute(self, *args, **kwargs):
#     974         """Simple passthrough to SQLAlchemy connectable"""
# --> 975         return self.connectable.execute(*args, **kwargs)
#     976
#     977     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in execute(self, statement, *multiparams, **params)
#    1987
#    1988         connection = self.contextual_connect(close_with_result=True)
# -> 1989         return connection.execute(statement, *multiparams, **params)
#    1990
#    1991     def scalar(self, statement, *multiparams, **params):
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in execute(self, object, *multiparams, **params)
#     904         """
#     905         if isinstance(object, util.string_types[0]):
# --> 906             return self._execute_text(object, multiparams, params)
#     907         try:
#     908             meth = object._execute_on_connection
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in _execute_text(self, statement, multiparams, params)
#    1052             statement,
#    1053             parameters,
# -> 1054             statement, parameters
#    1055         )
#    1056         if self._has_events or self.engine._has_events:
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1144                 parameters,
#    1145                 cursor,
# -> 1146                 context)
#    1147
#    1148         if self._has_events or self.engine._has_events:
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1339                 util.raise_from_cause(
#    1340                     sqlalchemy_exception,
# -> 1341                     exc_info
#    1342                 )
#    1343             else:
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sqlalchemy/util/compat.pyc in raise_from_cause(exception, exc_info)
#     197             exc_info = sys.exc_info()
#     198         exc_type, exc_value, exc_tb = exc_info
# --> 199         reraise(type(exception), exception, tb=exc_tb)
#     200
#     201 if py3k:
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1137                         statement,
#    1138                         parameters,
# -> 1139                         context)
#    1140         except Exception as e:
#    1141             self._handle_dbapi_exception(
#
# /Users/shajek/anaconda/lib/python2.7/site-packages/sqlalchemy/engine/default.pyc in do_execute(self, cursor, statement, parameters, context)
#     448
#     449     def do_execute(self, cursor, statement, parameters, context=None):
# --> 450         cursor.execute(statement, parameters)
#     451
#     452     def do_execute_no_params(self, cursor, statement, context=None):
#
# InternalError: (psycopg2.InternalError) cannot drop schema wnv because other objects depend on it
# HINT:  Use DROP ... CASCADE to drop the dependent objects too.
#  [SQL: 'DROP SCHEMA wnv;']

# %% [markdown]
# ## Load Data

# %%
traindf = pd.read_csv('../input/train.csv')
testdf = pd.read_csv('../input/test.csv')

# %%
schema = 'wnv'
traindf.to_sql('wnv_train', engine, schema=schema, index = False,
               if_exists = 'replace', chunksize=1000)

# %%
# %%read_sql
# SELECT *
# FROM wnv.wnv_train
# LIMIT 10
# Out:
# Query started at 04:13:35 PM EDT
# Query executed in 0.00 m
# <a id="1497989615"></a>
#
#         <script>
#         function notifyMe() {
#           if (Notification.permission !== "granted")
#             Notification.requestPermission();
#           else {
#             var notification = new Notification('Query Finished in 0.00 m', {
#               icon: 'https://raw.githubusercontent.com/crawles/Logos/master/jupyter.png?raw=true',
#               body: "04:13:35 PM EDT\n\nName: None\nDimensions: (10, 12)",
#             });
#
#             notification.onclick = function () {
#               document.getElementById('1497989615').scrollIntoView();
#             };
#
#           }
#         }
#         // prevents notifications from popping up when notebook is re-opened
#         if (Date.now() < 1.49798961639e+12) {
#         notifyMe(); };
#         </script>
#          Date                                            Address  \
# 0  2007-06-05  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-06-05  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-06-05  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 3  2007-06-05    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-06-05    7900 West Foster Avenue, Chicago, IL 60656, USA
# 5  2007-06-05   1500 West Webster Avenue, Chicago, IL 60614, USA
# 6  2007-06-05   1500 West Webster Avenue, Chicago, IL 60614, USA
# 7  2007-06-05   1500 West Webster Avenue, Chicago, IL 60614, USA
# 8  2007-06-05     2500 West Grand Avenue, Chicago, IL 60654, USA
# 9  2007-06-05        1100 Roosevelt Road, Chicago, IL 60608, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2           CULEX PIPIENS     41   N OAK PARK AVE  T002
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
# 5  CULEX PIPIENS/RESTUANS     15    W WEBSTER AVE  T045
# 6          CULEX RESTUANS     15    W WEBSTER AVE  T045
# 7           CULEX PIPIENS     15    W WEBSTER AVE  T045
# 8          CULEX RESTUANS     25      W GRAND AVE  T046
# 9  CULEX PIPIENS/RESTUANS     11      W ROOSEVELT  T048
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 3    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 4    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 5   1500  W WEBSTER AVE, Chicago, IL  41.921600 -87.666455                8
# 6   1500  W WEBSTER AVE, Chicago, IL  41.921600 -87.666455                8
# 7   1500  W WEBSTER AVE, Chicago, IL  41.921600 -87.666455                8
# 8     2500  W GRAND AVE, Chicago, IL  41.891118 -87.654491                8
# 9     1100  W ROOSEVELT, Chicago, IL  41.867108 -87.654224                8
#
#    NumMosquitos  WnvPresent
# 0             3           0
# 1             5           0
# 2             1           0
# 3             1           0
# 4             2           0
# 5             1           0
# 6             2           0
# 7             1           0
# 8             1           0
# 9             1           0
