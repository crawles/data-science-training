# %%
# %run db.ipynb
# Out:
# The sql_magic extension is already loaded. To reload it, use:
#   %reload_ext sql_magic
# Query started at 03:00:33 PM EDT
# Query executed in 0.00 m
# Query started at 03:00:33 PM EDT
# Query executed in 0.00 m

# %% [markdown]
# ## Load Data

# %%
traindf = pd.read_csv('../input/train.csv')
weatherdf = pd.read_csv('../input/weather.csv')
spraydf = pd.read_csv('../input/spray.csv')
# testdf = pd.read_csv('../input/test.csv')

# %%
schema = 'wnv'
traindf.to_sql('wnv_train', engine, schema=schema, index = False,
               if_exists = 'replace', chunksize=1000)
weatherdf.to_sql('wnv_weather', engine, schema=schema, index = False,
               if_exists = 'replace', chunksize=1000)
spraydf.to_sql('wnv_spray', engine, schema=schema, index = False,
               if_exists = 'replace', chunksize=1000)

# %%
# %%read_sql
# SELECT *
# FROM wnv.wnv_weather
# LIMIT 10
# Out:
# Query started at 03:09:56 PM EDT
# Query executed in 0.00 m
# <a id="1498072196"></a>
#
#         <script>
#         function notifyMe() {
#           if (Notification.permission !== "granted")
#             Notification.requestPermission();
#           else {
#             var notification = new Notification('Query Finished in 0.00 m', {
#               icon: 'https://raw.githubusercontent.com/crawles/Logos/master/jupyter.png?raw=true',
#               body: "03:09:56 PM EDT\n\nName: None\nDimensions: (10, 22)",
#             });
#
#             notification.onclick = function () {
#               document.getElementById('1498072196').scrollIntoView();
#             };
#
#           }
#         }
#         // prevents notifications from popping up when notebook is re-opened
#         if (Date.now() < 1.49807219766e+12) {
#         notifyMe(); };
#         </script>
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        2  2007-05-01    84    52   68      M        51      57    0    3
# 1        2  2007-05-02    60    43   52      M        42      47   13    0
# 2        2  2007-05-03    67    48   58      M        40      50    7    0
# 3        2  2007-05-04    78    51    M      M        42      50    M    M
# 4        2  2007-05-05    66    54   60      M        39      50    5    0
# 5        2  2007-05-06    68    52   60      M        30      46    5    0
# 6        2  2007-05-07    84    50   67      M        39      53    0    2
# 7        2  2007-05-08    80    60   70      M        57      63    0    5
# 8        2  2007-05-09    76    63   70      M        60      63    0    5
# 9        2  2007-05-10    83    59   71      M        52      61    0    6
#
#      ...    CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 0    ...                M      M        M        0.00       29.18    29.82
# 1    ...      BR HZ     M      M        M        0.00       29.44    30.08
# 2    ...         HZ     M      M        M        0.00       29.46    30.12
# 3    ...                M      M        M        0.00       29.36    30.04
# 4    ...                M      M        M           T       29.46    30.09
# 5    ...                M      M        M        0.00       29.62    30.28
# 6    ...                M      M        M        0.00       29.44    30.12
# 7    ...         HZ     M      M        M           T       29.36    30.02
# 8    ...      BR HZ     M      M        M        0.02       29.28    29.93
# 9    ...      BR HZ     M      M        M        0.00       29.26    29.91
#
#   ResultSpeed ResultDir  AvgSpeed
# 0         2.7        25       9.6
# 1        13.3         2      13.4
# 2        12.9         6      13.2
# 3        10.1         7      10.4
# 4        11.2         7      11.5
# 5        13.8        10      14.5
# 6         8.5        17       9.9
# 7         2.5         8       5.4
# 8         3.9         7       5.9
# 9         2.0         9       3.9
#
# [10 rows x 22 columns]
