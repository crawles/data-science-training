# %%
# %run ../db.ipynb
# %config SQL.notify_result = False

# %%
# %read_sql SET search_path TO ds_training_wnv;
# Out:
# Query started at 12:07:44 PM Eastern Daylight Time; Query executed in 0.00 m

# %%
input_table = 'wnv_train'

# %%
# %%read_sql _df
# SELECT *
# FROM {input_table}
# LIMIT 10
# Out:
# Query started at 04:39:30 PM Eastern Daylight Time
# Query executed in 0.00 m
#          date                                            address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 5  2007-05-29   1500 West Webster Avenue, Chicago, IL 60614, USA
# 6  2007-05-29     2500 West Grand Avenue, Chicago, IL 60654, USA
# 7  2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 8  2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 9  2007-05-29   1100 West Chicago Avenue, Chicago, IL 60642, USA
#
#                   species  block           street  trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
# 5          CULEX RESTUANS     15    W WEBSTER AVE  T045
# 6          CULEX RESTUANS     25      W GRAND AVE  T046
# 7  CULEX PIPIENS/RESTUANS     11      W ROOSEVELT  T048
# 8          CULEX RESTUANS     11      W ROOSEVELT  T048
# 9          CULEX RESTUANS     11        W CHICAGO  T049
#
#               addressnumberandstreet   latitude  longitude  addressaccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
# 3    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 4    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 5   1500  W WEBSTER AVE, Chicago, IL  41.921600 -87.666455                8
# 6     2500  W GRAND AVE, Chicago, IL  41.891118 -87.654491                8
# 7     1100  W ROOSEVELT, Chicago, IL  41.867108 -87.654224                8
# 8     1100  W ROOSEVELT, Chicago, IL  41.867108 -87.654224                8
# 9       1100  W CHICAGO, Chicago, IL  41.896282 -87.655232                8
#
#    nummosquitos  wnvpresent
# 0             1           0
# 1             1           0
# 2             1           0
# 3             1           0
# 4             4           0
# 5             2           0
# 6             1           0
# 7             1           0
# 8             2           0
# 9             1           0

# %% [markdown]
# # Casting as a date type

# %%
# %%read_sql
# SELECT date::date
# FROM wnv_train
# LIMIT 10
# Out:
# Query started at 04:39:34 PM Eastern Daylight Time
# Query executed in 0.00 m
#          date
# 0  2007-05-29
# 1  2007-05-29
# 2  2007-05-29
# 3  2007-05-29
# 4  2007-05-29
# 5  2007-05-29
# 6  2007-05-29
# 7  2007-05-29
# 8  2007-05-29
# 9  2007-05-29

# %% [markdown]
# # Extracting year, month, and day from a date

# %%
input_table = 'wnv_train'
output_table = 'wnv_train_ts'

# %%
# %%read_sql
# DROP TABLE if EXISTS {output_table};
# CREATE TABLE {output_table}
# AS
# WITH wnv_train_dates AS (
#                      SELECT date::date date_ts, *
#                      FROM {input_table}
#                      )
# SELECT extract(year from date_ts)::int AS year,
#        extract(month from date_ts)::int AS month,
#        extract(day from date_ts)::int AS day,
#        extract(doy from date_ts)::int AS day_of_year,
#        *
# FROM wnv_train_dates
# Out:
# Query started at 04:39:58 PM Eastern Daylight Time
# Query executed in 0.00 m
# Query started at 04:39:58 PM Eastern Daylight Time
# Query executed in 0.04 m

# %%
# %read_sql SELECT * FROM {output_table} LIMIT 10
# Out:
# Query started at 04:40:00 PM Eastern Daylight Time
# Query executed in 0.00 m
#    year  month  day  day_of_year     date_ts        date  \
# 0  2007      5   29          149  2007-05-29  2007-05-29
# 1  2007      5   29          149  2007-05-29  2007-05-29
# 2  2007      5   29          149  2007-05-29  2007-05-29
# 3  2007      5   29          149  2007-05-29  2007-05-29
# 4  2007      5   29          149  2007-05-29  2007-05-29
# 5  2007      5   29          149  2007-05-29  2007-05-29
# 6  2007      5   29          149  2007-05-29  2007-05-29
# 7  2007      5   29          149  2007-05-29  2007-05-29
# 8  2007      5   29          149  2007-05-29  2007-05-29
# 9  2007      5   29          149  2007-05-29  2007-05-29
#
#                                              address                 species  \
# 0  4100 North Oak Park Avenue, Chicago, IL 60634,...  CULEX PIPIENS/RESTUANS
# 1  4100 North Oak Park Avenue, Chicago, IL 60634,...          CULEX RESTUANS
# 2  6200 North Mandell Avenue, Chicago, IL 60646, USA          CULEX RESTUANS
# 3    7900 West Foster Avenue, Chicago, IL 60656, USA  CULEX PIPIENS/RESTUANS
# 4    7900 West Foster Avenue, Chicago, IL 60656, USA          CULEX RESTUANS
# 5   1500 West Webster Avenue, Chicago, IL 60614, USA          CULEX RESTUANS
# 6     2500 West Grand Avenue, Chicago, IL 60654, USA          CULEX RESTUANS
# 7        1100 Roosevelt Road, Chicago, IL 60608, USA  CULEX PIPIENS/RESTUANS
# 8        1100 Roosevelt Road, Chicago, IL 60608, USA          CULEX RESTUANS
# 9   1100 West Chicago Avenue, Chicago, IL 60642, USA          CULEX RESTUANS
#
#    block           street  trap             addressnumberandstreet   latitude  \
# 0     41   N OAK PARK AVE  T002  4100  N OAK PARK AVE, Chicago, IL  41.954690
# 1     41   N OAK PARK AVE  T002  4100  N OAK PARK AVE, Chicago, IL  41.954690
# 2     62    N MANDELL AVE  T007   6200  N MANDELL AVE, Chicago, IL  41.994991
# 3     79     W FOSTER AVE  T015    7900  W FOSTER AVE, Chicago, IL  41.974089
# 4     79     W FOSTER AVE  T015    7900  W FOSTER AVE, Chicago, IL  41.974089
# 5     15    W WEBSTER AVE  T045   1500  W WEBSTER AVE, Chicago, IL  41.921600
# 6     25      W GRAND AVE  T046     2500  W GRAND AVE, Chicago, IL  41.891118
# 7     11      W ROOSEVELT  T048     1100  W ROOSEVELT, Chicago, IL  41.867108
# 8     11      W ROOSEVELT  T048     1100  W ROOSEVELT, Chicago, IL  41.867108
# 9     11        W CHICAGO  T049       1100  W CHICAGO, Chicago, IL  41.896282
#
#    longitude  addressaccuracy  nummosquitos  wnvpresent
# 0 -87.800991                9             1           0
# 1 -87.800991                9             1           0
# 2 -87.769279                9             1           0
# 3 -87.824812                8             1           0
# 4 -87.824812                8             4           0
# 5 -87.666455                8             2           0
# 6 -87.654491                8             1           0
# 7 -87.654224                8             1           0
# 8 -87.654224                8             2           0
# 9 -87.655232                8             1           0

# %% [markdown]
# # Aggregate to Trap, Species, Level
#
# We are asked to predict for a given day, trap, and species, predict the presence of West Nile Virus in mosquitoes.

# %%
input_table = 'wnv_train_ts'
output_table = 'wnv_train_agg'

# %%
# %%read_sql
# DROP TABLE IF EXISTS {output_table};
# CREATE TABLE {output_table}
# AS
# SELECT date_ts,year,month,day,day_of_year,trap,latitude,longitude,species,
#        SUM(NumMosquitos)::int total_num_mosquitos,
#        MAX(WnvPresent) wnv_present
# FROM {input_table}
# GROUP BY date_ts,year,month,day,day_of_year,trap,latitude,longitude,species
# Out:
# Query started at 04:40:06 PM Eastern Daylight Time
# Query executed in 0.00 m
# Query started at 04:40:06 PM Eastern Daylight Time
# Query executed in 0.03 m

# %%
# %%read_sql
# SELECT *
# FROM {output_table}
# Out:
# Query started at 04:40:07 PM Eastern Daylight Time
# Query executed in 0.05 m
#          date_ts  year  month  day  day_of_year   trap   latitude  longitude  \
# 0     2007-08-01  2007      8    1          213   T086  41.688324 -87.676709
# 1     2009-09-14  2009      9   14          257   T225  41.743402 -87.731435
# 2     2007-08-01  2007      8    1          213   T085  41.721474 -87.648064
# 3     2009-07-17  2009      7   17          198   T073  41.773215 -87.600880
# 4     2011-06-30  2011      6   30          181   T082  41.803423 -87.642984
# 5     2013-07-25  2013      7   25          206   T230  41.904194 -87.756155
# 6     2009-06-15  2009      6   15          166   T209  41.740641 -87.546587
# 7     2013-08-22  2013      8   22          234   T027  41.984809 -87.728492
# 8     2013-07-19  2013      7   19          200   T114  41.798697 -87.736812
# 9     2011-09-01  2011      9    1          244   T223  41.973845 -87.805059
# 8468  CULEX PIPIENS/RESTUANS                    1            0
# 8469          CULEX RESTUANS                    4            0
# 8470  CULEX PIPIENS/RESTUANS                   18            0
# 8471  CULEX PIPIENS/RESTUANS                    6            0
# 8472  CULEX PIPIENS/RESTUANS                    3            0
# 8473  CULEX PIPIENS/RESTUANS                   11            0
# 8474          CULEX RESTUANS                    3            0
#
# [8475 rows x 11 columns]

# %% [markdown]
# # Categorical Variable Enconding

# %%
input_table = 'wnv_train_agg' 
output_table = 'wnv_train_agg_dummy'

# %%
df = %read_sql SELECT species FROM {input_table}
# Out:
# Query started at 03:56:45 PM Eastern Daylight Time
# Query executed in 0.02 m

# %%
import re
species = ['CULEX PIPIENS/RESTUANS',
 'CULEX RESTUANS',
 'CULEX PIPIENS',
 'CULEX TERRITANS',
 'CULEX SALINARIUS',
 'CULEX TARSALIS',
 'CULEX ERRATICUS']
def _clean_dummy_val( cval):
    """For creating dummy variable columns, we need to remove special characters in values"""
    cval_clean = cval.replace(' ','_').replace('-','_').replace('"','').replace("'",'')
    return re.sub('[^a-zA-Z\d\s:]', '_', cval_clean)
def to_dummy(c, c_value):
    c_val_clean = _clean_dummy_val(c_value)
    return "CAST({c}='{c_value}' AS int) AS {c}_{c_val_clean}".format(c=c,
                                                                    c_value = c_value,
                                                                    c_val_clean = c_val_clean
                                                              )

cols = %read_sql SELECT * FROM {input_table} LIMIT 0
cols = cols.columns.tolist()
cols.remove('species')
sql = cols + [to_dummy('species', c) for c in species]
sql_str = ',\n'.join(sql)
# Out:
# Query started at 04:04:49 PM Eastern Daylight Time
# Query executed in 0.00 m
# date_ts,
# year,
# month,
# day,
# day_of_year,
# trap,
# latitude,
# longitude,
# total_num_mosquitos,
# wnv_present,
# CAST(species='CULEX PIPIENS/RESTUANS' AS int) AS species_CULEX_PIPIENS_RESTUANS,
# CAST(species='CULEX RESTUANS' AS int) AS species_CULEX_RESTUANS,
# CAST(species='CULEX PIPIENS' AS int) AS species_CULEX_PIPIENS,
# CAST(species='CULEX TERRITANS' AS int) AS species_CULEX_TERRITANS,
# CAST(species='CULEX SALINARIUS' AS int) AS species_CULEX_SALINARIUS,
# CAST(species='CULEX TARSALIS' AS int) AS species_CULEX_TARSALIS,
# CAST(species='CULEX ERRATICUS' AS int) AS species_CULEX_ERRATICUS

# %%
# %%read_sql
# DROP TABLE IF EXISTS {output_table};
# CREATE TABLE {output_table}
# AS
# SELECT {sql_str}
# FROM {input_table};
# Out:
# Query started at 04:05:34 PM Eastern Daylight Time
# Query executed in 0.00 m
# Query started at 04:05:34 PM Eastern Daylight Time
# Query executed in 0.03 m

# %%
# %read_sql SELECT madlib.create_indicator_variables()
# Out:
# Query started at 03:38:35 PM Eastern Daylight Time
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-4-20591cec35ce> in <module>()
# ----> 1 get_ipython().magic(u'read_sql SELECT madlib.create_indicator_variables()')
#
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\interactiveshell.pyc in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-123> in read_sql(self, line, cell, local_ns)
#
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\sql_magic.pyc in read_sql(self, line, cell, local_ns)
#     141             t.start()
#     142         else:
# --> 143             result = self.conn.execute_sqls(statements, options)
#     144             if options['display']:
#     145                 return result
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\connection.pyc in execute_sqls(self, sqls, options)
#     139         """Execute a list of sql statements"""
#     140         for i, s in enumerate(sqls, start=1):
# --> 141             r = self._read_sql_engine(s, options)
#     142         return r  # return last result
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\connection.pyc in _read_sql_engine(self, sql, options)
#     116         if caller is None:
#     117             raise ConnectionNotConfigured("A connection object must be configured using %config SQL.conn_name")
# --> 118         result, del_time = self._time_and_run_query(caller, sql)
#     119
#     120         if table_name:
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\connection.pyc in _time_and_run_query(self, caller, sql)
#     130         print('Query started at {}'.format(pretty_start_time))
#     131         start_time = time.time()
# --> 132         result = caller(sql)
#     133         end_time = time.time()
#     134         del_time = (end_time - start_time) / 60.
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\connection.pyc in _run_db_sql(sql_code)
#      62         def _run_db_sql(sql_code):
#      63             try:
# ---> 64                 return psql.read_sql(sql_code, conn_object)
#      65             except(tuple(self.no_return_result_exceptions)):
#      66                 return EmptyResult()
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\sql.pyc in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     398             sql, index_col=index_col, params=params,
#     399             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 400             chunksize=chunksize)
#     401
#     402     try:
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\sql.pyc in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1437
#    1438         args = _convert_params(sql, params)
# -> 1439         cursor = self.execute(*args)
#    1440         columns = [col_desc[0] for col_desc in cursor.description]
#    1441
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\sql.pyc in execute(self, *args, **kwargs)
#    1414             ex = DatabaseError(
#    1415                 "Execution failed on sql '%s': %s" % (args[0], exc))
# -> 1416             raise_with_traceback(ex)
#    1417
#    1418     @staticmethod
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\sql.pyc in execute(self, *args, **kwargs)
#    1402                 cur.execute(*args, **kwargs)
#    1403             else:
# -> 1404                 cur.execute(*args)
#    1405             return cur
#    1406         except Exception as exc:
#
# DatabaseError: Execution failed on sql 'SELECT madlib.create_indicator_variables()': function madlib.create_indicator_variables(unknown) does not exist
# LINE 2:     SELECT madlib.create_indicator_variables('');
#                    ^
# HINT:  No function matches the given name and argument types. You may need to add explicit type casts.
# QUERY:
#     SELECT madlib.create_indicator_variables('');
#
# CONTEXT:  SQL function "create_indicator_variables" during inlining

# %%
# %%read_sql
# DROP TABLE IF EXISTS {output_table};
# SELECT madlib.create_indicator_variables('{input_table}',
#                                          '{output_table}',
#                                          'species')
# Out:
# Query started at 12:07:57 PM Eastern Daylight Time; Query executed in 0.01 mQuery started at 12:07:57 PM Eastern Daylight Time
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-4-f92fe8f49cf3> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'read_sql', u'', u"DROP TABLE IF EXISTS {output_table};\nSELECT madlib.create_indicator_variables('{input_table}',\n                                         '{output_table}',\n                                         'species')")
#
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-123> in read_sql(self, line, cell, local_ns)
#
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\sql_magic.pyc in read_sql(self, line, cell, local_ns)
#     141             t.start()
#     142         else:
# --> 143             result = self.conn.execute_sqls(statements, options)
#     144             if options['display']:
#     145                 return result
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\connection.pyc in execute_sqls(self, sqls, options)
#     144         r = None
#     145         for i, s in enumerate(sqls, start=1):
# --> 146             r = self._read_sql_engine(s, options)
#     147         return r  # return last result
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\connection.pyc in _read_sql_engine(self, sql, options)
#     116         if caller is None:
#     117             raise ConnectionNotConfigured("A connection object must be configured using %config SQL.conn_name")
# --> 118         result, del_time, time_output = self._time_and_run_query(caller, sql)
#     119
#     120         if table_name:
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\connection.pyc in _time_and_run_query(self, caller, sql)
#     132         sys.stdout.write(time_output)
#     133         start_time = time.time()
# --> 134         result = caller(sql)
#     135         end_time = time.time()
#     136         del_time = (end_time - start_time) / 60.
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\connection.pyc in _run_db_sql(sql_code)
#      62         def _run_db_sql(sql_code):
#      63             try:
# ---> 64                 return psql.read_sql(sql_code, conn_object)
#      65             except(tuple(self.no_return_result_exceptions)):
#      66                 return EmptyResult()
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\sql.pyc in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     398             sql, index_col=index_col, params=params,
#     399             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 400             chunksize=chunksize)
#     401
#     402     try:
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\sql.pyc in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1437
#    1438         args = _convert_params(sql, params)
# -> 1439         cursor = self.execute(*args)
#    1440         columns = [col_desc[0] for col_desc in cursor.description]
#    1441
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\sql.pyc in execute(self, *args, **kwargs)
#    1414             ex = DatabaseError(
#    1415                 "Execution failed on sql '%s': %s" % (args[0], exc))
# -> 1416             raise_with_traceback(ex)
#    1417
#    1418     @staticmethod
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\sql.pyc in execute(self, *args, **kwargs)
#    1402                 cur.execute(*args, **kwargs)
#    1403             else:
# -> 1404                 cur.execute(*args)
#    1405             return cur
#    1406         except Exception as exc:
#
# DatabaseError: Execution failed on sql 'SELECT madlib.create_indicator_variables('wnv_train_agg',
#                                          'wnv_train_agg_dummy',
#                                          'species')': function madlib.create_indicator_variables(text, text, text, boolean) does not exist
# LINE 2:     SELECT madlib.create_indicator_variables($1, $2, $3, Fal...
#                    ^
# HINT:  No function matches the given name and argument types. You may need to add explicit type casts.
# QUERY:
#     SELECT madlib.create_indicator_variables($1, $2, $3, False)
#
# CONTEXT:  SQL function "create_indicator_variables" during inlining

# %%
# %read_sql SELECT * FROM {output_table}
# Out:
# Query started at 04:40:14 PM Eastern Daylight Time
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-26-51c26f632df7> in <module>()
# ----> 1 get_ipython().magic(u'read_sql SELECT * FROM {output_table}')
#
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\interactiveshell.pyc in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-123> in read_sql(self, line, cell, local_ns)
#
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\sql_magic.pyc in read_sql(self, line, cell, local_ns)
#     141             t.start()
#     142         else:
# --> 143             result = self.conn.execute_sqls(statements, options)
#     144             if options['display']:
#     145                 return result
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\connection.pyc in execute_sqls(self, sqls, options)
#     139         """Execute a list of sql statements"""
#     140         for i, s in enumerate(sqls, start=1):
# --> 141             r = self._read_sql_engine(s, options)
#     142         return r  # return last result
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\connection.pyc in _read_sql_engine(self, sql, options)
#     116         if caller is None:
#     117             raise ConnectionNotConfigured("A connection object must be configured using %config SQL.conn_name")
# --> 118         result, del_time = self._time_and_run_query(caller, sql)
#     119
#     120         if table_name:
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\connection.pyc in _time_and_run_query(self, caller, sql)
#     130         print('Query started at {}'.format(pretty_start_time))
#     131         start_time = time.time()
# --> 132         result = caller(sql)
#     133         end_time = time.time()
#     134         del_time = (end_time - start_time) / 60.
#
# C:\ProgramData\Anaconda2\lib\site-packages\sql_magic\connection.pyc in _run_db_sql(sql_code)
#      62         def _run_db_sql(sql_code):
#      63             try:
# ---> 64                 return psql.read_sql(sql_code, conn_object)
#      65             except(tuple(self.no_return_result_exceptions)):
#      66                 return EmptyResult()
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\sql.pyc in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     398             sql, index_col=index_col, params=params,
#     399             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 400             chunksize=chunksize)
#     401
#     402     try:
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\sql.pyc in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1437
#    1438         args = _convert_params(sql, params)
# -> 1439         cursor = self.execute(*args)
#    1440         columns = [col_desc[0] for col_desc in cursor.description]
#    1441
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\sql.pyc in execute(self, *args, **kwargs)
#    1414             ex = DatabaseError(
#    1415                 "Execution failed on sql '%s': %s" % (args[0], exc))
# -> 1416             raise_with_traceback(ex)
#    1417
#    1418     @staticmethod
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\sql.pyc in execute(self, *args, **kwargs)
#    1402                 cur.execute(*args, **kwargs)
#    1403             else:
# -> 1404                 cur.execute(*args)
#    1405             return cur
#    1406         except Exception as exc:
#
# DatabaseError: Execution failed on sql 'SELECT * FROM wnv_train_agg_dummy': relation "wnv_train_agg_dummy" does not exist
# LINE 1: SELECT * FROM wnv_train_agg_dummy
#                       ^

# %% [markdown]
# # Weather Data

# %% [markdown]
# # Data Cleansing and Missing Values
#
# Need to remove whitespace and replace characters with empty

# %%
input_table = 'wnv_weather' 
output_table = 'wnv_trimmed'

# %%
# %read_sql SELECT * FROM wnv_weather LIMIT 10
# Out:
# Query started at 03:52:08 PM Eastern Daylight Time
# Query executed in 0.01 m
#    station        date  tmax  tmin tavg depart  dewpoint wetbulb heat cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
# 5        2  2007-05-03    67    48   58      M        40      50    7    0
# 6        1  2007-05-04    66    49   58      4        41      50    7    0
# 7        2  2007-05-04    78    51    M      M        42      50    M    M
# 8        1  2007-05-05    66    53   60      5        38      49    5    0
# 9        2  2007-05-05    66    54   60      M        39      50    5    0
#
#      ...    codesum depth water1 snowfall preciptotal stnpressure sealevel  \
# 0    ...                0      M      0.0        0.00       29.10    29.82
# 1    ...                M      M        M        0.00       29.18    29.82
# 2    ...         BR     0      M      0.0        0.00       29.38    30.09
# 3    ...      BR HZ     M      M        M        0.00       29.44    30.08
# 4    ...                0      M      0.0        0.00       29.39    30.12
# 5    ...         HZ     M      M        M        0.00       29.46    30.12
# 6    ...         RA     0      M      0.0           T       29.31    30.05
# 7    ...                M      M        M        0.00       29.36    30.04
# 8    ...                0      M      0.0           T       29.40    30.10
# 9    ...                M      M        M           T       29.46    30.09
#
#   resultspeed resultdir  avgspeed
# 0         1.7        27       9.2
# 1         2.7        25       9.6
# 2        13.0         4      13.4
# 3        13.3         2      13.4
# 4        11.7         7      11.9
# 5        12.9         6      13.2
# 6        10.4         8      10.8
# 7        10.1         7      10.4
# 8        11.7         7      12.0
# 9        11.2         7      11.5
#
# [10 rows x 22 columns]

# %% [markdown]
# # Trim White Space

# %%
# %%read_sql
# DROP TABLE IF EXISTS {output_table};
# CREATE TEMP TABLE {output_table}
# AS
# SELECT *,
#        trim(avgspeed) avgspeed_trimmed,
#        trim(preciptotal) preciptotal_trimmed,
#        trim(tmin) tmin_trimmed,
#        trim(tavg) tavg_trimmed,
#        trim(tmax) tmax_trimmed
# FROM {input_table}
# Out:
# Query started at 03:52:11 PM Eastern Daylight Time
# Query executed in 0.00 m
# Query started at 03:52:11 PM Eastern Daylight Time
# Query executed in 0.05 m

# %%
input_table = 'wnv_trimmed'
output_table = 'wnv_weather_clean'

# %% [markdown]
# # Replacing Missing Variables

# %%
# %%read_sql
# DROP TABLE IF EXISTS {output_table};
# CREATE TABLE {output_table}
# AS
# SELECT date,
#        CAST(regexp_replace(avgspeed_trimmed, '^[^\d.]+$', 0) AS float) AS avgspeed,
#        CAST(regexp_replace(preciptotal_trimmed, '^[^\d.]+$', 0) AS float) AS preciptotal,
#        CAST(regexp_replace(tmin_trimmed, '^[^\\d.]+$', 0) AS float) AS tmin,
#        CAST(regexp_replace(tavg_trimmed, '^[^\\d.]+$', 0) AS float) AS tavg,
#        CAST(regexp_replace(tmax_trimmed, '^[^\\d.]+$', 0) AS float) AS tmax
# FROM {input_table}
# Out:
# Query started at 03:52:21 PM Eastern Daylight Time
# Query executed in 0.00 m
# Query started at 03:52:21 PM Eastern Daylight Time
# Query executed in 0.02 m

# %% [markdown]
# # Create weather date features (same as for station data)
#
# This analysis is the same as used for the station data so we have filled it in.

# %%
input_table = 'wnv_weather_clean'
output_table = 'wnv_weather_ts'

# %%
# %%read_sql
# DROP TABLE if EXISTS {output_table};
# CREATE TABLE {output_table}
# AS
# WITH wnv_weather_dates AS (
#                           SELECT date::date date_ts, *
#                           FROM {input_table}
#                           )
# SELECT extract(year from date_ts)::int AS year,
#        extract(month from date_ts)::int AS month,
#        extract(day from date_ts)::int AS day,
#        extract(doy from date_ts)::int AS day_of_year,
#        *
# FROM wnv_weather_dates
# Out:
# Query started at 03:52:24 PM Eastern Daylight Time
# Query executed in 0.00 m
# Query started at 03:52:24 PM Eastern Daylight Time
# Query executed in 0.03 m

# %%
# %%read_sql
# SELECT *
# FROM {output_table}
# LIMIT 10
# Out:
# Query started at 03:52:26 PM Eastern Daylight Time
# Query executed in 0.13 m
#    year  month  day  day_of_year     date_ts        date  avgspeed  \
# 0  2007      5    1          121  2007-05-01  2007-05-01       9.2
# 1  2007      5    1          121  2007-05-01  2007-05-01       9.6
# 2  2007      5    2          122  2007-05-02  2007-05-02      13.4
# 3  2007      5    2          122  2007-05-02  2007-05-02      13.4
# 4  2007      5    3          123  2007-05-03  2007-05-03      11.9
# 5  2007      5    3          123  2007-05-03  2007-05-03      13.2
# 6  2007      5    4          124  2007-05-04  2007-05-04      10.8
# 7  2007      5    4          124  2007-05-04  2007-05-04      10.4
# 8  2007      5    5          125  2007-05-05  2007-05-05      12.0
# 9  2007      5    5          125  2007-05-05  2007-05-05      11.5
#
#    preciptotal  tmin  tavg  tmax
# 0          0.0  50.0  67.0  83.0
# 1          0.0  52.0  68.0  84.0
# 2          0.0  42.0  51.0  59.0
# 3          0.0  43.0  52.0  60.0
# 4          0.0  46.0  56.0  66.0
# 5          0.0  48.0  58.0  67.0
# 6          0.0  49.0  58.0  66.0
# 7          0.0  51.0   0.0  78.0
# 8          0.0  53.0  60.0  66.0
# 9          0.0  54.0  60.0  66.0

# %% [markdown]
# # Compute Weather Averages

# %%
input_table = 'wnv_weather_ts'
output_table = 'wnv_weather_rolling'

# %%
# %%read_sql
# DROP TABLE IF EXISTS {output_table};
# CREATE TABLE {output_table}
# AS
# SELECT date_ts,
#        avg(avgspeed) OVER (ORDER BY date_ts RANGE BETWEEN 7 PRECEDING AND CURRENT ROW),
#        avg(preciptotal) OVER (ORDER BY date_ts RANGE BETWEEN 7 PRECEDING AND CURRENT ROW) AS preciptotal7,
#        avg(tmin) OVER (ORDER BY date_ts RANGE BETWEEN 7 PRECEDING AND CURRENT ROW) AS tmin7,
#        avg(tavg) OVER (ORDER BY date_ts RANGE BETWEEN 7 PRECEDING AND CURRENT ROW) AS tavg7,
#        avg(tmax) OVER (ORDER BY date_ts RANGE BETWEEN 7 PRECEDING AND CURRENT ROW) AS tmax7
# FROM {input_table}
# ORDER BY date_ts
# Out:
# Query started at 03:52:34 PM Eastern Daylight Time
# Query executed in 0.00 m
# Query started at 03:52:34 PM Eastern Daylight Time
# Query executed in 0.09 m

# %%
# %%read_sql
# SELECT *
# FROM {output_table}
# LIMIT 10
# Out:
# Query started at 03:52:39 PM Eastern Daylight Time
# Query executed in 0.00 m
#       date_ts        avg  preciptotal7      tmin7      tavg7      tmax7
# 0  2007-05-01   9.400000           0.0  51.000000  67.500000  83.500000
# 1  2007-05-01   9.400000           0.0  51.000000  67.500000  83.500000
# 2  2007-05-02  11.400000           0.0  46.750000  59.500000  71.500000
# 3  2007-05-02  11.400000           0.0  46.750000  59.500000  71.500000
# 4  2007-05-03  11.783333           0.0  46.833333  58.666667  69.833333
# 5  2007-05-03  11.783333           0.0  46.833333  58.666667  69.833333
# 6  2007-05-04  11.487500           0.0  47.625000  51.250000  70.375000
# 7  2007-05-04  11.487500           0.0  47.625000  51.250000  70.375000
# 8  2007-05-05  11.540000           0.0  48.800000  53.000000  69.500000
# 9  2007-05-05  11.540000           0.0  48.800000  53.000000  69.500000

# %% [markdown]
# # Putting it All Together: Join weather data and mosquito station data

# %%
station_table = 'wnv_train_agg_dummy'
weather_table = 'wnv_weather_rolling'
output_table = 'wnv_features'

# %%
df = %read_sql SELECT * FROM {station_table} LIMIT 10
df.columns.tolist()
# Out:
# Query started at 04:11:07 PM Eastern Daylight Time
# Query executed in 0.00 m
# ['date_ts',
#  'year',
#  'month',
#  'day',
#  'day_of_year',
#  'trap',
#  'latitude',
#  'longitude',
#  'total_num_mosquitos',
#  'wnv_present',
#  'species_culex_pipiens_restuans',
#  'species_culex_restuans',
#  'species_culex_pipiens',
#  'species_culex_territans',
#  'species_culex_salinarius',
#  'species_culex_tarsalis',
#  'species_culex_erraticus']

# %%
# %%read_sql
# DROP TABLE IF EXISTS {output_table};
# CREATE TABLE {output_table}
# AS
# SELECT row_number() OVER () as id, *
# FROM {station_table}
# INNER JOIN {weather_table}
# USING (date_ts);
# Out:
# Query started at 04:06:31 PM Eastern Daylight Time
# Query executed in 0.00 m
# Query started at 04:06:31 PM Eastern Daylight Time
# Query executed in 0.06 m

# %%
print(1)
# Out:
# 1
